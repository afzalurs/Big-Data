# %% [markdown]
# <a href="https://colab.research.google.com/github/afzalurs/Big-Data/blob/main/GEOLOCATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopy
import pandas as pd

# %%
from geopy.geocoders import Nominatim
import time
from pprint import pprint

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="example app")

# %%
import folium
from folium.plugins import MarkerCluster

# %%
#marker_cluster = MarkerCluster().add_to(m)

# %%
import requests
import json
import urllib
base_url= "https://maps.googleapis.com/maps/api/geocode/json?"
AUTH_KEY ="AIzaSyALnM3plARAzQmqJ_HsHfBD_u89mEQXzs4" #AIzaSyAvtgBb36e7_iUK8uTo702E5Yd-v9MuW5k

# %%
df=pd.read_csv("https://raw.githubusercontent.com/afzalurs/Big-Data/main/dataset/students.csv")

# %%
df
# Out:
#                         Name                 City     District          State
# 0  AFZALUR RAHAMAN CHOUDHURY              Silchar       Cachar          ASSAM
# 1              KRISHAN KUMAR             MUNDAWAR        ALWAR      RAJASTHAN
# 2      DHIRENDRA SINGH MAHRA      VAISHALI COLONY     KASHIPUR    UTTARAKHAND
# 3                      FAYIZ             Kuttiady    Kozhikode         KERALA
# 4                INDU KUMARI             SAKATPUR    DARBHANGA          BIHAR
# 5        MUSHAHID NAZIR BHAT  GULSHANPORA BAGTORE        GUREZ       SRINAGAR
# 6           UTKARSH VARSHNEY         Braham Bazar    Chandausi  UTTAR PRADESH
# 7              JAYANTI SINGH            BAGUIHATI      KOLKATA     WESTBENGAL
# 8                ROHIT KUMAR                LAVAD  GANDHINAGAR        GUJARAT

# %%
df.columns
# Out:
# Index(['Name', 'City', 'District', 'State'], dtype='object')

# %%
df['Address']=df['City'] + ' ,' + df['District']+ ' ,' + df['State']

# %%
from geopy.extra.rate_limiter import RateLimiter
# 1 - conveneint function to delay between geocoding calls
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
# 2- - create location column
df['location'] = df['City'].apply(geocode)

# %%
df
# Out:
#                         Name                 City     District          State  \
# 0  AFZALUR RAHAMAN CHOUDHURY              Silchar       Cachar          ASSAM
# 1              KRISHAN KUMAR             MUNDAWAR        ALWAR      RAJASTHAN
# 2      DHIRENDRA SINGH MAHRA      VAISHALI COLONY     KASHIPUR    UTTARAKHAND
# 3                      FAYIZ             Kuttiady    Kozhikode         KERALA
# 4                INDU KUMARI             SAKATPUR    DARBHANGA          BIHAR
# 5        MUSHAHID NAZIR BHAT  GULSHANPORA BAGTORE        GUREZ       SRINAGAR
# 6           UTKARSH VARSHNEY         Braham Bazar    Chandausi  UTTAR PRADESH
# 7              JAYANTI SINGH            BAGUIHATI      KOLKATA     WESTBENGAL
# 8                ROHIT KUMAR                LAVAD  GANDHINAGAR        GUJARAT
#
#                                   Address  \
# 0                  Silchar ,Cachar ,ASSAM
# 1              MUNDAWAR ,ALWAR ,RAJASTHAN
# 2  VAISHALI COLONY ,KASHIPUR ,UTTARAKHAND
# ...

# %%
# 3 - create longitude, laatitude and altitude from location column (returns tuple)
df['point'] = df['location'].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
# 4 - split point column into latitude, longitude and altitude columns
df[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df['point'].tolist(), index=df.index)

# %%
df.head()
# Out:
#                         Name             City   District        State  \
# 0  AFZALUR RAHAMAN CHOUDHURY          Silchar     Cachar        ASSAM
# 1              KRISHAN KUMAR         MUNDAWAR      ALWAR    RAJASTHAN
# 2      DHIRENDRA SINGH MAHRA  VAISHALI COLONY   KASHIPUR  UTTARAKHAND
# 3                      FAYIZ         Kuttiady  Kozhikode       KERALA
# 4                INDU KUMARI         SAKATPUR  DARBHANGA        BIHAR
#
#                                   Address  \
# 0                  Silchar ,Cachar ,ASSAM
# 1              MUNDAWAR ,ALWAR ,RAJASTHAN
# 2  VAISHALI COLONY ,KASHIPUR ,UTTARAKHAND
# 3             Kuttiady ,Kozhikode ,KERALA
# 4              SAKATPUR ,DARBHANGA ,BIHAR
#
#                                             location  \
# 0  (Silchar, Cachar, Assam, India, (24.8178611000...
# 1  (Mundawar, Gurugram, Haryana, India, (28.28263...
# 2  (Vaishali, Wrangler Parajape Path, Electoral W...
# 3  (Police Station, Kuttiady, Puthiyangadi - Koot...
# ...

# %%
df.columns
# Out:
# Index(['Name', 'City', 'District', 'State', 'Address', 'location', 'point',
#        'latitude', 'longitude', 'altitude'],
#       dtype='object')

# %%
#drop the unwanted columns
df = df.drop(['Name', 'City', 'District', 'State', 'Address', 'location', 'point'], axis=1)

# %%
df.head()
# Out:
#     latitude  longitude  altitude
# 0  24.817861  92.756221       0.0
# 1  28.282633  77.161755       0.0
# 2  18.520848  73.841218       0.0
# 3  11.652045  75.753501       0.0
# 4  28.054030  79.322062       0.0

# %%
df=df.dropna(subset=['longitude'])

df=df.dropna(subset=['latitude'])

# %%
#Creating a map of given locations
import folium
map1 = folium.Map(
    location=[59.338315,18.089960],
    tiles='cartodbpositron',
    zoom_start=12,
)
df.apply(lambda row:folium.CircleMarker(location=[row["latitude"], row["longitude"]]).add_to(map1), axis=1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Creating the Dark Map with Fast Marker Cluster

from folium.plugins import FastMarkerCluster
folium_map = folium.Map(location=[59.338315,18.089960],
                        zoom_start=20,
                        tiles='CartoDB dark_matter')


FastMarkerCluster(data=list(zip(df['latitude'].values, df['longitude'].values))).add_to(folium_map)
folium.LayerControl().add_to(folium_map)
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from geopy.distance import great_circle
print(great_circle('Silchar', 'Bathinda').km)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-ae6eb4042d65> in <module>()
#       1 from geopy.distance import great_circle
# ----> 2 print(great_circle('Silchar', 'Bathinda').km)
#
# /usr/local/lib/python3.7/dist-packages/geopy/distance.py in __init__(self, *args, **kwargs)
#     299     def __init__(self, *args, **kwargs):
#     300         self.RADIUS = kwargs.pop('radius', EARTH_RADIUS)
# --> 301         super(great_circle, self).__init__(*args, **kwargs)
#     302
#     303     def measure(self, a, b):
#
# /usr/local/lib/python3.7/dist-packages/geopy/distance.py in __init__(self, *args, **kwargs)
#     162         elif len(args) > 1:
#     163             for a, b in util.pairwise(args):
# --> 164                 kilometers += self.measure(a, b)
#     165
#     166         kilometers += units.kilometers(**kwargs)
#
# ...

# %%
pip install gmplot

# %%
# import gmplot package
import gmplot

# GoogleMapPlotter return Map object
# Pass the center latitude and
# center longitude
gmap1 = gmplot.GoogleMapPlotter(31.6339793, 74.8722642, 13 )
print(gmap1)
# Pass the absolute path
#gmap1.draw( "map11.html" )

# %%
gmap1
